# %%
import sqlite3
import re

import pandas
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from numpy import zeros

nlp = spacy.load("en_core_web_lg")

pandas.set_option("display.max_rows", 200)

# %%
connection = sqlite3.connect("b2b_google_analytics.db")

# %%
# Joining with content_preview returns 0 results.
relevant_tables = ["keyword_search", "browse_navigation", "content_retrievals"]

df = pandas.DataFrame()
for table in relevant_tables:
    this_df = pandas.read_sql(("SELECT " + ("k.query" if table == "keyword_search" else "k.event_label") +
                               " AS user, s.event_label AS suggestion " 
                               "FROM {} k INNER JOIN suggested_search s ON "
                               "s.user_id = k.user_id AND s.event_time = k.event_time".format(table)), connection)
    this_df["table"] = table
    df = df.append(this_df, ignore_index=True)

df["ignore"] = df["user"].apply(lambda x : ("persons.code:" in x or "subjects.code:" in x
                                            or "places.code:" in x))
df = df[df["ignore"] == False]
del df["ignore"]

df
# Out:
#                                                   user  \
# 0                                   Vermont Daily Life
# 1                                     \"Donald Trump\"
# 2                                Donald Trump portrait
# 4                                       kelly loeffler
# 5                                          real estate
# 6                     Election 2020 Looking At America
# 8                                                  usa
# 9                                                  usa
# 10                                           missisipi
# 11                                 PENNSYLVANIA ballot
# 12                                               Biden
# 13                                      lindsey graham
# 14   Republican Lindsey Graham wins reelection to U...
# 15   Republican Lindsey Graham wins reelection to U...
# 16                                              senate
# 17                                     today n histiry
# 18                       Election 2020 Arkansas Voting
# 19                               Election 2020 INDIANA
# 20                       Election 2020 Colorado Voting
# 21                              West Virginia, Justice
# 22        West Virginia, Justice, republican governor,
# 23                                            cawthorn
# 24                                            cawthorn
# 25                                               Klopp
# 26   US election 2020 live updates Trump vs Biden a...
# 27                                        usa election
# 28                                                 usa
# 29                                        TURKEY QUAKE
# 30                                            missouri
# 31                                                 aoc
# 32                                          new jersey
# 33                                        election day
# 34                                            nebraska
# 35                                               Bihar
# 39                                            laturner
# 40                                    Missouri (State)
# 41                                         White house
# 42                                         White house
# 43                                            AUSTRAIA
# 44                                            AUSTRAIA
# 45    New Jersey voters approve recreational marijuana
# 46                                        donald trump
# 47   Republican Markwayne Mullin wins reelection to...
# 48   Republican Markwayne Mullin wins reelection to...
# 49                                               Biden
# 55                           US Presidential Elections
# 57   Marjorie Taylor Greene a Republican who expres...
# 58                              President Donald Trump
# 59                                     President Trump
# 61                                       body Language
# 65                           Donald Trump US President
# 66                                         amy mcgrath
# 67                                              sports
# 68                                       Election 2020
# 69                                       american flag
# 70                                        donald trump
# 71                                        donald trump
# 72                                        donald trump
# 73                                        donald trump
# 74                                        donald trump
# 75                                        donald trump
# 78                                               Biden
# 79                               Mitch McConnell smile
# 81                                   adriano espaillat
# 82                                            oddities
# 83                                            oddities
# 84                                            oddities
# 85                                                nypd
# 86                                     Unrest New York
# 87                                               Trump
# 88                                 election 2020 trump
# 89                           2020 Election 03 Nov 2020
# 90                           2020 Election 03 Тщм 2020
# 91                               Kanye West 3 nov 2020
# 92                      Jonathan Isaac (Orlando Magic)
# 93                                              cornyn
# 94                         Election 2020 Senate Cornyn
# 95                                  U.S. Election 2020
# 96              Visuals (Photo, Video, Graphic, Audio)
# 97              Visuals (Photo, Video, Graphic, Audio)
# 98              Visuals (Photo, Video, Graphic, Audio)
# 99                      AP News Alerts (2020 Election)
# 100                                  VoteCast Coverage
# 101                                          (not set)
# 102                                           Top News
# 103                                          (not set)
# 104                              California State News
# 105                                          (not set)
# 106                                  All Newest Photos
# 107                                    US--APNewsAlert
# 108                US--Election 2020-Senate-The Latest
# 109  53282a7da4f3a1903358b4b16d8a17a6, 41fe2b185f9d...
# 110          Gospel star Bishop Rance Allen dead at 71
# 111                              Whitey Bulger-Lawsuit
# 112                      APTOPIX Austria Vienna Attack
# 113                                Election 2020 Biden
# 114           US--Election 2020-Senate-Rocky Mountains
# 115                               Cruise Ships-No Sail
# 116                       Election 2020 Indiana Voting
# 117              IL--Election 2020-News Guide-Illinois
# 118                  Election 2020 House Ocasio-Cortez
# 119  With quarterback Garbers leading the way, Cal ...
# 120                                Election 2020 Trump
# 121                Election 2020 Protest Washington DC
# 122                          Election 2020 White House
# 123                                Election 2020 Trump
# 124                         Argentina Maradona Surgery
# 125                          Election 2020 Utah Voting
# 126                         Election 2020 Pennsylvania
# 127                                 Election 2020 Ohio
# 128                                Election 2020 Trump
# 129                            Nicaragua Hurricane Eta
#
#                                             suggestion               table
# 0                                   Vermont Daily Life      keyword_search
# 1                               Joe Biden Donald Trump      keyword_search
# 2                                         Donald Trump      keyword_search
# 4    Republican Kelly Loeffler advances to runoff e...      keyword_search
# 5                                      Home and garden      keyword_search
# 6                     Election 2020 Looking At America      keyword_search
# 8                                        Election 2020      keyword_search
# 9                                        Election 2020      keyword_search
# 10                           VoteCast Mississippi Race      keyword_search
# 11                                 PENNSYLVANIA VOTING      keyword_search
# 12                                       Election 2020      keyword_search
# 13   Republican Lindsey Graham wins reelection to U...      keyword_search
# 14   Republican Lindsey Graham wins reelection to U...      keyword_search
# 15   Republican Lindsey Graham wins reelection to U...      keyword_search
# 16                         Lindsey Graham (politician)      keyword_search
# 17                                    Today in History      keyword_search
# 18                              Election 2020 Arkansas      keyword_search
# 19                              Election 2020 Arkansas      keyword_search
# 20                  Election 2020 Massachusetts Voting      keyword_search
# 21                  Election 2020 West Virginia Voting      keyword_search
# 22                  Election 2020 West Virginia Voting      keyword_search
# 23   Madison Cawthorn wins western North Carolina U...      keyword_search
# 24   Republican Madison Cawthorn wins election to U...      keyword_search
# 25                    Presidential election in the USA      keyword_search
# 26   US election 2020 live updates Trump vs Biden a...      keyword_search
# 27                           USA Presidential Election      keyword_search
# 28                           USA Presidential Election      keyword_search
# 29   2 children rescued in Turkey as quake death to...      keyword_search
# 30                                   Missouri Football      keyword_search
# 31               Alexandria Ocasio-Cortez (politician)      keyword_search
# 32                                   Cannabis (plants)      keyword_search
# 33              Election Day No Sports Voting Activism      keyword_search
# 34                                    Nebraska (State)      keyword_search
# 35                                India State Election      keyword_search
# 39                                    Missouri (State)      keyword_search
# 40                                    Missouri (State)      keyword_search
# 41                                         White House      keyword_search
# 42                                         White House      keyword_search
# 43                               Austria Vienna Attack      keyword_search
# 44                               Austria Vienna Attack      keyword_search
# 45    New Jersey voters approve recreational marijuana      keyword_search
# 46                                        Donald Trump      keyword_search
# 47                       Markwayne Mullin (politician)      keyword_search
# 48   Republican Markwayne Mullin wins reelection to...      keyword_search
# 49                                     Scranton (City)      keyword_search
# 55                           US Presidential Elections      keyword_search
# 57   Marjorie Taylor Greene a Republican who expres...      keyword_search
# 58           Joe Biden Democratic presidential nominee      keyword_search
# 59           Joe Biden Democratic presidential nominee      keyword_search
# 61                                            Language      keyword_search
# 65                           Donald Trump US President      keyword_search
# 66                        Mitch McConnell (politician)      keyword_search
# 67                                            Baseball      keyword_search
# 68                                       Election 2020      keyword_search
# 69                                        Election Day      keyword_search
# 70                                        Donald Trump      keyword_search
# 71                                        Donald Trump      keyword_search
# 72                                        Donald Trump      keyword_search
# 73                                        Donald Trump      keyword_search
# 74                                        Donald Trump      keyword_search
# 75                                        Donald Trump      keyword_search
# 78                                 Philadelphia (City)      keyword_search
# 79                        Mitch McConnell (politician)      keyword_search
# 81   Democrat Adriano Espaillat wins reelection to ...      keyword_search
# 82                                            Oddities      keyword_search
# 83                                            Oddities      keyword_search
# 84                                            Oddities      keyword_search
# 85   NY Bracing for Election Unrest Stores are Boar...      keyword_search
# 86   NY Bracing for Election Unrest Stores are Boar...      keyword_search
# 87                                 Election 2020 Trump      keyword_search
# 88                  2020 Election New Hampshire Voting      keyword_search
# 89                                Election 2020 Global      keyword_search
# 90                                Election 2020 Global      keyword_search
# 91                               Kanye West (musician)      keyword_search
# 92                      Jonathan Isaac (Orlando Magic)      keyword_search
# 93                         Election 2020 Senate Cornyn      keyword_search
# 94                         Election 2020 Senate Cornyn      keyword_search
# 95                          Election 2020 Philadelphia   browse_navigation
# 96                          Election 2020 Philadelphia   browse_navigation
# 97                                     EEUU ELECCIONES   browse_navigation
# 98                         Election 2020 Melania Trump   browse_navigation
# 99                              Election 2020 Virginia   browse_navigation
# 100                          USA Presidential Election   browse_navigation
# 101                                  Cannabis (plants)   browse_navigation
# 102                                      Sarah McBride   browse_navigation
# 103                           Adam Schiff (politician)   browse_navigation
# 104                           Adam Schiff (politician)   browse_navigation
# 105                                      Entertainment   browse_navigation
# 106                               VIENNA TERROR ATTACK   browse_navigation
# 107  Republican Mitch McConnell wins reelection to ...  content_retrievals
# 108  Republican Mitch McConnell wins reelection to ...  content_retrievals
# 109                              Austria Vienna Attack  content_retrievals
# 110                             Rance Allen (musician)  content_retrievals
# 111                              Whitey Bulger Lawsuit  content_retrievals
# 112                      APTOPIX Austria Vienna Attack  content_retrievals
# 113                             Joe Biden (politician)  content_retrievals
# 114                          Cory Gardner (politician)  content_retrievals
# 115  Cruise industry throws in the towel on 2020 lo...  content_retrievals
# 116                       Election 2020 Indiana Voting  content_retrievals
# 117                             Election 2020 Illinois  content_retrievals
# 118              Alexandria Ocasio-Cortez (politician)  content_retrievals
# 119                   California Golden Bears football  content_retrievals
# 120                                       Donald Trump  content_retrievals
# 121                                        White House  content_retrievals
# 122                                        White House  content_retrievals
# 123                                       Donald Trump  content_retrievals
# 124                              Diego Maradona soccer  content_retrievals
# 125                          Election 2020 Utah Voting  content_retrievals
# 126                         Election 2020 Pennsylvania  content_retrievals
# 127  Ohio pivotal in presidential race US House sea...  content_retrievals
# 128                                Election 2020 Trump  content_retrievals
# 129  Powerful Hurricane Eta threatens flooding in C...  content_retrievals

# %%
def get_vector(x):
    vector = zeros(300)
    for token in nlp(re.sub(r'[\'",\?\.\*\(\)\\]', "", x, re.U)):
        #print(token.text)
        if token.has_vector:
            vector = vector + token.vector
    return vector

# %%
def compare(u, s):
    # for addressing OOV issues, data's too old
    if u.lower() == "cawthorn" and "cawthorn" in s.lower():
        return 0.75
    if u == "aoc" and s == "Alexandria Ocasio-Cortez (politician)":
        return 1.0
    return cosine_similarity([get_vector(u)], [get_vector(s)])[0][0]

# %%
df["CS"] = df.apply(lambda x : compare(x["user"], x["suggestion"]), axis=1)

# %%
df["CS"].describe()
# Out:
# count    112.000000
# mean       0.643127
# std        0.337530
# min       -0.136085
# 25%        0.369081
# 50%        0.726827
# 75%        1.000000
# max        1.000000
# Name: CS, dtype: float64

# %%
len(df.query('user == suggestion | CS == 1.0')) / len(df)
# Out:
# 0.17857142857142858

# %%
df.query('CS > 0 & CS < 1').groupby(["table"]).agg({"CS" : "mean"})
# Out:
#                           CS
# table
# browse_navigation   0.316320
# content_retrievals  0.657223
# keyword_search      0.651637

# %%
df[df["table"] == "browse_navigation"].sort_values(by="CS")
# Out:
#                                        user                   suggestion  \
# 97   Visuals (Photo, Video, Graphic, Audio)              EEUU ELECCIONES
# 102                                Top News                Sarah McBride
# 103                               (not set)     Adam Schiff (politician)
# 98   Visuals (Photo, Video, Graphic, Audio)  Election 2020 Melania Trump
# 96   Visuals (Photo, Video, Graphic, Audio)   Election 2020 Philadelphia
# 106                       All Newest Photos         VIENNA TERROR ATTACK
# 101                               (not set)            Cannabis (plants)
# 104                   California State News     Adam Schiff (politician)
# 105                               (not set)                Entertainment
# 100                       VoteCast Coverage    USA Presidential Election
# 99           AP News Alerts (2020 Election)       Election 2020 Virginia
# 95                       U.S. Election 2020   Election 2020 Philadelphia
#
#                  table        CS
# 97   browse_navigation -0.136085
# 102  browse_navigation  0.081042
# 103  browse_navigation  0.106812
# 98   browse_navigation  0.124434
# 96   browse_navigation  0.147255
# 106  browse_navigation  0.226766
# 101  browse_navigation  0.274294
# 104  browse_navigation  0.307815
# 105  browse_navigation  0.334776
# 100  browse_navigation  0.346832
# 99   browse_navigation  0.729745
# 95   browse_navigation  0.799755

# %%
df[df["table"] == "content_retrievals"].sort_values(by="CS")
# Out:
#                                                   user  \
# 109  53282a7da4f3a1903358b4b16d8a17a6, 41fe2b185f9d...
# 114           US--Election 2020-Senate-Rocky Mountains
# 121                Election 2020 Protest Washington DC
# 107                                    US--APNewsAlert
# 123                                Election 2020 Trump
# 120                                Election 2020 Trump
# 119  With quarterback Garbers leading the way, Cal ...
# 108                US--Election 2020-Senate-The Latest
# 115                               Cruise Ships-No Sail
# 129                            Nicaragua Hurricane Eta
# 110          Gospel star Bishop Rance Allen dead at 71
# 127                                 Election 2020 Ohio
# 118                  Election 2020 House Ocasio-Cortez
# 113                                Election 2020 Biden
# 117              IL--Election 2020-News Guide-Illinois
# 122                          Election 2020 White House
# 124                         Argentina Maradona Surgery
# 111                              Whitey Bulger-Lawsuit
# 126                         Election 2020 Pennsylvania
# 116                       Election 2020 Indiana Voting
# 112                      APTOPIX Austria Vienna Attack
# 125                          Election 2020 Utah Voting
# 128                                Election 2020 Trump
#
#                                             suggestion               table  \
# 109                              Austria Vienna Attack  content_retrievals
# 114                          Cory Gardner (politician)  content_retrievals
# 121                                        White House  content_retrievals
# 107  Republican Mitch McConnell wins reelection to ...  content_retrievals
# 123                                       Donald Trump  content_retrievals
# 120                                       Donald Trump  content_retrievals
# 119                   California Golden Bears football  content_retrievals
# 108  Republican Mitch McConnell wins reelection to ...  content_retrievals
# 115  Cruise industry throws in the towel on 2020 lo...  content_retrievals
# 129  Powerful Hurricane Eta threatens flooding in C...  content_retrievals
# 110                             Rance Allen (musician)  content_retrievals
# 127  Ohio pivotal in presidential race US House sea...  content_retrievals
# 118              Alexandria Ocasio-Cortez (politician)  content_retrievals
# 113                             Joe Biden (politician)  content_retrievals
# 117                             Election 2020 Illinois  content_retrievals
# 122                                        White House  content_retrievals
# 124                              Diego Maradona soccer  content_retrievals
# 111                              Whitey Bulger Lawsuit  content_retrievals
# 126                         Election 2020 Pennsylvania  content_retrievals
# 116                       Election 2020 Indiana Voting  content_retrievals
# 112                      APTOPIX Austria Vienna Attack  content_retrievals
# 125                          Election 2020 Utah Voting  content_retrievals
# 128                                Election 2020 Trump  content_retrievals
#
#            CS
# 109  0.000000
# 114  0.181127
# 121  0.342487
# 107  0.376497
# 123  0.486370
# 120  0.486370
# 119  0.513090
# 108  0.535699
# 115  0.580488
# 129  0.588003
# 110  0.606967
# 127  0.634519
# 118  0.639697
# 113  0.682465
# 117  0.709781
# 122  0.753981
# 124  0.763280
# 111  0.920857
# 126  1.000000
# 116  1.000000
# 112  1.000000
# 125  1.000000
# 128  1.000000

# %%
df[df["table"] == "keyword_search"].sort_values(by="CS")
# Out:
#                                                  user  \
# 43                                           AUSTRAIA
# 44                                           AUSTRAIA
# 39                                           laturner
# 10                                          missisipi
# 25                                              Klopp
# 81                                  adriano espaillat
# 85                                               nypd
# 8                                                 usa
# 9                                                 usa
# 32                                         new jersey
# 49                                              Biden
# 78                                              Biden
# 12                                              Biden
# 4                                      kelly loeffler
# 69                                      american flag
# 35                                              Bihar
# 47  Republican Markwayne Mullin wins reelection to...
# 66                                        amy mcgrath
# 16                                             senate
# 5                                         real estate
# 28                                                usa
# 13                                     lindsey graham
# 93                                             cornyn
# 17                                    today n histiry
# 87                                              Trump
# 29                                       TURKEY QUAKE
# 91                              Kanye West 3 nov 2020
# 67                                             sports
# 58                             President Donald Trump
# 59                                    President Trump
# 86                                    Unrest New York
# 21                             West Virginia, Justice
# 23                                           cawthorn
# 24                                           cawthorn
# 89                          2020 Election 03 Nov 2020
# 30                                           missouri
# 61                                      body Language
# 22       West Virginia, Justice, republican governor,
# 90                          2020 Election 03 Тщм 2020
# 79                              Mitch McConnell smile
# 88                                election 2020 trump
# 34                                           nebraska
# 33                                       election day
# 2                               Donald Trump portrait
# 1                                    \"Donald Trump\"
# 11                                PENNSYLVANIA ballot
# 27                                       usa election
# 19                              Election 2020 INDIANA
# 18                      Election 2020 Arkansas Voting
# 20                      Election 2020 Colorado Voting
# 26  US election 2020 live updates Trump vs Biden a...
# 92                     Jonathan Isaac (Orlando Magic)
# 15  Republican Lindsey Graham wins reelection to U...
# 45   New Jersey voters approve recreational marijuana
# 14  Republican Lindsey Graham wins reelection to U...
# 42                                        White house
# 41                                        White house
# 0                                  Vermont Daily Life
# 94                        Election 2020 Senate Cornyn
# 31                                                aoc
# 48  Republican Markwayne Mullin wins reelection to...
# 6                    Election 2020 Looking At America
# 46                                       donald trump
# 72                                       donald trump
# 73                                       donald trump
# 70                                       donald trump
# 71                                       donald trump
# 75                                       donald trump
# 74                                       donald trump
# 65                          Donald Trump US President
# 68                                      Election 2020
# 57  Marjorie Taylor Greene a Republican who expres...
# 40                                   Missouri (State)
# 83                                           oddities
# 84                                           oddities
# 55                          US Presidential Elections
# 82                                           oddities
#
#                                            suggestion           table  \
# 43                              Austria Vienna Attack  keyword_search
# 44                              Austria Vienna Attack  keyword_search
# 39                                   Missouri (State)  keyword_search
# 10                          VoteCast Mississippi Race  keyword_search
# 25                   Presidential election in the USA  keyword_search
# 81  Democrat Adriano Espaillat wins reelection to ...  keyword_search
# 85  NY Bracing for Election Unrest Stores are Boar...  keyword_search
# 8                                       Election 2020  keyword_search
# 9                                       Election 2020  keyword_search
# 32                                  Cannabis (plants)  keyword_search
# 49                                    Scranton (City)  keyword_search
# 78                                Philadelphia (City)  keyword_search
# 12                                      Election 2020  keyword_search
# 4   Republican Kelly Loeffler advances to runoff e...  keyword_search
# 69                                       Election Day  keyword_search
# 35                               India State Election  keyword_search
# 47                      Markwayne Mullin (politician)  keyword_search
# 66                       Mitch McConnell (politician)  keyword_search
# 16                        Lindsey Graham (politician)  keyword_search
# 5                                     Home and garden  keyword_search
# 28                          USA Presidential Election  keyword_search
# 13  Republican Lindsey Graham wins reelection to U...  keyword_search
# 93                        Election 2020 Senate Cornyn  keyword_search
# 17                                   Today in History  keyword_search
# 87                                Election 2020 Trump  keyword_search
# 29  2 children rescued in Turkey as quake death to...  keyword_search
# 91                              Kanye West (musician)  keyword_search
# 67                                           Baseball  keyword_search
# 58          Joe Biden Democratic presidential nominee  keyword_search
# 59          Joe Biden Democratic presidential nominee  keyword_search
# 86  NY Bracing for Election Unrest Stores are Boar...  keyword_search
# 21                 Election 2020 West Virginia Voting  keyword_search
# 23  Madison Cawthorn wins western North Carolina U...  keyword_search
# 24  Republican Madison Cawthorn wins election to U...  keyword_search
# 89                               Election 2020 Global  keyword_search
# 30                                  Missouri Football  keyword_search
# 61                                           Language  keyword_search
# 22                 Election 2020 West Virginia Voting  keyword_search
# 90                               Election 2020 Global  keyword_search
# 79                       Mitch McConnell (politician)  keyword_search
# 88                 2020 Election New Hampshire Voting  keyword_search
# 34                                   Nebraska (State)  keyword_search
# 33             Election Day No Sports Voting Activism  keyword_search
# 2                                        Donald Trump  keyword_search
# 1                              Joe Biden Donald Trump  keyword_search
# 11                                PENNSYLVANIA VOTING  keyword_search
# 27                          USA Presidential Election  keyword_search
# 19                             Election 2020 Arkansas  keyword_search
# 18                             Election 2020 Arkansas  keyword_search
# 20                 Election 2020 Massachusetts Voting  keyword_search
# 26  US election 2020 live updates Trump vs Biden a...  keyword_search
# 92                     Jonathan Isaac (Orlando Magic)  keyword_search
# 15  Republican Lindsey Graham wins reelection to U...  keyword_search
# 45   New Jersey voters approve recreational marijuana  keyword_search
# 14  Republican Lindsey Graham wins reelection to U...  keyword_search
# 42                                        White House  keyword_search
# 41                                        White House  keyword_search
# 0                                  Vermont Daily Life  keyword_search
# 94                        Election 2020 Senate Cornyn  keyword_search
# 31              Alexandria Ocasio-Cortez (politician)  keyword_search
# 48  Republican Markwayne Mullin wins reelection to...  keyword_search
# 6                    Election 2020 Looking At America  keyword_search
# 46                                       Donald Trump  keyword_search
# 72                                       Donald Trump  keyword_search
# 73                                       Donald Trump  keyword_search
# 70                                       Donald Trump  keyword_search
# 71                                       Donald Trump  keyword_search
# 75                                       Donald Trump  keyword_search
# 74                                       Donald Trump  keyword_search
# 65                          Donald Trump US President  keyword_search
# 68                                      Election 2020  keyword_search
# 57  Marjorie Taylor Greene a Republican who expres...  keyword_search
# 40                                   Missouri (State)  keyword_search
# 83                                           Oddities  keyword_search
# 84                                           Oddities  keyword_search
# 55                          US Presidential Elections  keyword_search
# 82                                           Oddities  keyword_search
#
#           CS
# 43  0.000000
# 44  0.000000
# 39  0.000000
# 10  0.000000
# 25  0.000000
# 81  0.043228
# 85  0.129856
# 8   0.139934
# 9   0.139934
# 32  0.177192
# 49  0.183761
# 78  0.184449
# 12  0.271295
# 4   0.340156
# 69  0.340740
# 35  0.378911
# 47  0.414780
# 66  0.446095
# 16  0.452538
# 5   0.520134
# 28  0.528098
# 13  0.551203
# 93  0.577237
# 17  0.588957
# 87  0.588972
# 29  0.622935
# 91  0.640894
# 67  0.647473
# 58  0.658458
# 59  0.663529
# 86  0.724070
# 21  0.729583
# 23  0.750000
# 24  0.750000
# 89  0.773853
# 30  0.781004
# 61  0.790692
# 22  0.799743
# 90  0.817754
# 79  0.821959
# 88  0.823662
# 34  0.829388
# 33  0.853699
# 2   0.864785
# 1   0.867425
# 11  0.911175
# 27  0.935268
# 19  0.936871
# 18  0.945446
# 20  0.948000
# 26  1.000000
# 92  1.000000
# 15  1.000000
# 45  1.000000
# 14  1.000000
# 42  1.000000
# 41  1.000000
# 0   1.000000
# 94  1.000000
# 31  1.000000
# 48  1.000000
# 6   1.000000
# 46  1.000000
# 72  1.000000
# 73  1.000000
# 70  1.000000
# 71  1.000000
# 75  1.000000
# 74  1.000000
# 65  1.000000
# 68  1.000000
# 57  1.000000
# 40  1.000000
# 83  1.000000
# 84  1.000000
# 55  1.000000
# 82  1.000000
